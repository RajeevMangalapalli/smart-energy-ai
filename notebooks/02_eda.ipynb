# %% [markdown]
# ## ACF, PACF plots
#
# - The goal here is to plot the following:
# 1. ACF features
# 2. PACF features
# 3. STL features
#
# - The reason being, finding out how to pick p,d,q features for the ARIMA model
# - Observing the patterns in the Time series
